# %%
import requests, base64
from io import BytesIO
from PIL import Image
from IPython.display import display

cristal = -25.43900347750803, -49.28128517766543
castelo = -25.442444059310613, -49.28575979312195
ed_asa = -25.43188285765169, -49.27605438684823
pucpr = -25.451376951255053, -49.252777095141084
jd_botanico = -25.440793108803657, -49.237824902742794
museu = -25.409689697407796, -49.267060498223586
torre = -25.424018797077057, -49.29405137264106
ouro_fino = -24.996358655009765, -49.02705781638185
pico_marumbi = -25.44143390372285, -48.91460293567934
mirante = -25.47427673417167, -49.37857169050803 # passauna
passauna = -25.531417164785577, -49.38315688140852 # entrada
cabana = -25.501460412412808, -49.36641387345384 # passauna
haras = -25.49548204119312, -49.364266535708275 #passauna
recanto_graciosa = -25.360007774423313, -48.97740718421961
angelina_caron = -25.346367232290167, -49.08102649246937
radio_A = -25.746627, -53.01808
radio_B = -25.77999, -53.0108


import cisei_lib.io.geo_notebook as gn
import cisei_lib.core.profiles.geo_info as gi
import importlib
importlib.reload(gn)
geo = gn.GeoNotebook()
geo.register('edgard')
geo.link(radio_A, radio_B)
# geo.link_profile(0.6, figsize=(15,5), dpi=100)
gi.test(link, 'DTM')
# Out:
# ✅ ready_for_provisioning
# ✅ link DEM e BLDG is initialized
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[19], line 32
#      28 geo = gn.GeoNotebook()
#      29 geo.register('edgard')
#      30 geo.link(radio_A, radio_B)
#      31 # geo.link_profile(0.6, figsize=(15,5), dpi=100)
# ---> 32 geo.test(link, 'DTM')
#
# AttributeError: 'GeoNotebook' object has no attribute 'test'

# %% [markdown]
# ### EXEMPLO DE CHAMADAS
# - use geo.doc('nome da api') para obter o help

# %%
geo.link(haras, mirante, rx_ha=20)
geo.doc('link')
# Out:
# ✅ link DEM e BLDG is initialized
# *** link ***
# Updates the active link stored in the backend runtime..
#
# Mandatory params
# ----------
# tx : (lat, lon)
# rx : (lat, lon)
#
# Optional (must include param name)
# ----------
# tx_ha: tx antenna height in meters (default = 7)
# rx_ha: rx antenna height in meters (default = 7)
# freq_mhz: frequency of the RF signal in mHz (default = 900)
# tx_ha_abs: tx absolute antenna height (including DTM) in meters
# rx_ha_abs: tx absolute antenna height (including DTM) in meters
# on_rooftop: add building height automatically (True or False)
#
# Return:
# ---------
# JSON response from the backend. Access payload with `result.data`.

# %%
geo.link(haras, mirante)
geo.dem_tiles('COVER', downscale = 20)
# Out:
# ✅ link DEM e BLDG is initialized
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=912x790>

# %%
geo.link(torre, pucpr)
#geo.doc('link_area')
geo.link_area('COVER')
geo.link_area('DTM')
geo.link_area('DSM')
# Out:
# ✅ link DEM e BLDG is initialized
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=569x397>
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=559x397>
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=559x397>

# %%
#geo.doc('link_profile')
geo.link(radio_A, radio_B)
geo.link_profile(0.6, figsize=(15,5), dpi=100)
geo.lulc_fresnel(dpi=115)
geo.dem_profiles(0,1, grid_alpha=0.9, h_tree=10, h_build=0, dpi=80)
# Out:
# ✅ link DEM e BLDG is initialized
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1158x470>
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=383x524>
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=981x488>

# %%
lat, lon = mirante
params = dict(lat=lat,lon=lon)
geo.call_api('get_canopy_height', params )

# %%
geo.link(radio_A, radio_B)
geo.link_profile(0.6, figsize=(15,5), dpi=100)
geo.dem_surface('DTM', figsize=(13,5), point_size=50)
geo.dem_surface('COVER', point_size=20, figsize=(12,5))
# Out:
# ❌ list index out of range
# '❌ Error: link is not set'
# "❌ Client error: argument should be a bytes-like object or ASCII string, not 'NoneType'"
# "❌ Client error: argument should be a bytes-like object or ASCII string, not 'NoneType'"

# %%
geo.link(pucpr, jd_botanico, tx_ha=15)
geo.bldg_prepare()
#geo.bldg_fresnel(dpi=200)
#geo.bldg_profile(figsize=(20,5))
geo.bldg_invasions()
# Out:
# ✅ link DEM e BLDG is initialized
# ✅ link BLDG is loaded

# %%
geo.bldg_filter(v_v=-0.6, v_h=-0.6)

# %%
geo.bldg_browser(order_by_invasion=True)
# Out:
# ✅ building browsing prepared

# %%
geo.bldg_next_invasion()
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=843x460>

# %%
geo.link(pucpr, jd_botanico, tx_ha=1, rx_ha=5)
geo.bldg_profile(figsize=(20,5))
# Out:
# ✅ link DEM e BLDG is initialized
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1631x460>

# %%
geo.link_features()

# %%
user
