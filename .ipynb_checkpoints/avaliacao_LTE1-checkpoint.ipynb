# %%
import geo_notebook as gn
geo = gn.GeoNotebook()
geo.register('edgard')

'''
rel3: 8187915243 ---> gia (Colombo-SE Guaraituba - Torre 52 metros) ----- em NB-IoT
rel2: 8831608089 ---> ud_sjp (UD_SJPinhais - Torre 31 metros) ---- em CAT-M
rel1: 8831612457 ---> ud_sjp (UD_SJPinhais - Torre 31 metros) ---- em CAT-M
'''

rel1 = -25.56108889, -49.17411389
rel2 = -25.54696667, -49.20072778
rel3 = -25.38485000, -49.18335000
ud_sjp = -25.534569, -49.191277
gia = -25.345578, -49.191444
geo.set_interactive(False)
# Out:
# ✅ ready_for_provisioning

# %% [markdown]
# # AVALIAÇÃO DO LINK 8831608089 ---> UD_SJPinhais (Torre 31 metros)

# %%
geo.link(rel2, ud_sjp, tx_ha=7, rx_ha=31, freq_mhz=450)
# Out:
# ✅ link DEM e BLDG is initialized

# %%
geo.link_profile(0)
geo.link_area('COVER')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=811x470>
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=467x455>

# %%
geo.bldg_prepare()
geo.bldg_fresnel()
geo.bldg_profile()
# Out:
# ✅ link BLDG is loaded
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=874x460>
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=856x460>

# %%
#geo.bldg_filter(v_v=-0.6, v_h=-0.6)

# %% [markdown]
# ## CARACTERISTICAS DO LINK

# %%
data = geo.link_features();
# Out:
# {
#     "fspl": 92.63,
#     "dist_m": 1669.88,
#     "delta_diffra": 0,
#     "terrain": {
#         "core": 0,
#         "fresnel": 22.5,
#         "boundary": 263.12
#     },
#     "vegetation": {
#         "core": 0,
#         "fresnel": 0,
#         "boundary": 0
#     },
#     "buildings": {
#         "core": 238.96,
#         "fresnel": 961.38,
#         "boundary": 818.98
#     },
#     "terrain_peaks_vv": [
#         {
#             "v_v": 0.43,
#             "d_norm": 0.21
#         },
#         {
#             "v_v": 0.01,
#             "d_norm": 0.1
#         }
#     ],
#     "max_obstruction_angle_rad": 0,
#     "tx_rx_elevation_angle_rad": -0.0,
#     "tx_near_terminal_clearance_m": 7.32,
#     "rx_near_terminal_clearance_m": 30.67
# }
