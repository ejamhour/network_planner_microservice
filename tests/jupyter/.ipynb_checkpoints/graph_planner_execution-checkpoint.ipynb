# %% [markdown]
# # GraphPlanner Scenario Execution
#
# This notebook consumes scenario bundles created by `planner_classes_tutorial.ipynb`.
#
# `PlanningScenario` is responsible for configuration and node instances. `GraphPlanner` loads the scenario, builds the candidate graph, computes metrics, and runs RPL.

# %%
from pathlib import Path

NOTEBOOK_DIR = Path.cwd()
NOTEBOOK_DIR
# Out:
# PosixPath('/workspaces/network_service/tests/jupyter')

# %%
from cisei_lib.io.async_geo_service_pool import AsyncGeoServicePool
from cisei_lib.planners import GraphPlanner, PlanningScenario
import cisei_lib.planners.planner_reports as reports

SCENARIO_DIR = NOTEBOOK_DIR / "scenario_exports"
RESULT_DIR = NOTEBOOK_DIR / "planning_results"
RESULT_DIR.mkdir(parents=True, exist_ok=True)
SINGLE_INTERFACE = SCENARIO_DIR / "graph_planner_single_interface.toml"
TWO_INTERFACE = SCENARIO_DIR / "graph_planner_two_interface.toml"

GEO_BASE_URL = "http://planning-service:8080"
GEO_USER_PREFIX = "graph-planner-demo"
GEO_POOL_SIZE = 2

# %% [markdown]
# ## 1. Load A Scenario Bundle
#
# Choose one of the generated scenarios. `GraphPlanner.from_toml` loads the TOML and automatically imports the companion node CSV declared in `[instances]`.

# %%
'''
try:
    await geo.close()
except Exception:
    print('Not running')
    pass
'''

geo = AsyncGeoServicePool(
    base_url=GEO_BASE_URL,
    user_prefix=GEO_USER_PREFIX,
    pool_size=GEO_POOL_SIZE,
    timeout=120,
)

await geo.start()
# Out:
# APIResult(kind='json')
# APIResult(kind='json')

# %%
# SCENARIO_PATH = SINGLE_INTERFACE
SCENARIO_PATH = TWO_INTERFACE

scenario = PlanningScenario.from_toml(SCENARIO_PATH)
planner = GraphPlanner.from_scenario(scenario)
candidate_edges = planner.build_candidate_edges_from_rules()
candidate_graph = planner.candidate_graph()

edge_metrics = await planner.compute_edge_metrics(
    geo,
    manage_geo=False, # True avoid cache reuse
)

planner.run_rpl()

# %%
reports.draw_network_graph(
    planner.rpl.G_res,
    label_mode="index",
    spread_same_position=True,
)

result = planner.to_result_dict()
planner.save_results("planning_results/my_result.json")
# Out:
# PosixPath('planning_results/my_result.json')

# %%
from cisei_lib.planners import AntennaPlanner

ap = AntennaPlanner()
ap.antenna_ids()
ap.gain_dbi("pctel_boa9028", frequency_mhz=915)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 from cisei_lib.planners import AntennaPlanner
#       2
#       3 ap = AntennaPlanner()
#       4 ap.antenna_ids()
#
# ImportError: cannot import name 'AntennaPlanner' from 'cisei_lib.planners' (/workspaces/network_service/cisei_lib/planners/__init__.py)
