# %%
import geo_notebook as gn
geo = gn.GeoNotebook()
geo.register('edgard')

'''
rel3: 8187915243 ---> gia (Colombo-SE Guaraituba - Torre 52 metros) ----- em NB-IoT
rel2: 8831608089 ---> ud_sjp (UD_SJPinhais - Torre 31 metros) ---- em CAT-M
rel1: 8831612457 ---> ud_sjp (UD_SJPinhais - Torre 31 metros) ---- em CAT-M
'''

rel1 = -25.56108889, -49.17411389
rel2 = -25.54696667, -49.20072778
rel3 = -25.38485000, -49.18335000
ud_sjp = -25.534569, -49.191277
gia = -25.345578, -49.191444
geo.set_interactive(False)
# Out:
# ✅ ready_for_provisioning

# %% [markdown]
# # AVALIAÇÃO DO LINK 8187915243 ---> UD_SJPinhais (Torre 31 metros)

# %%
geo.link(rel3, ud_sjp, tx_ha=7, rx_ha=31, freq_mhz=450)
# Out:
# ✅ link DEM e BLDG is initialized

# %%
geo.link_profile(0)
geo.link_area('COVER')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=829x470>
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=438x455>

# %%
geo.bldg_prepare()
geo.bldg_fresnel()
geo.bldg_profile()
# Out:
# ✅ link BLDG is loaded
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=865x460>
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=840x460>

# %% [markdown]
# ## CARACTERISTICAS DO LINK

# %%
data = geo.link_features();
# Out:
# {
#     "fspl": 109.92,
#     "dist_m": 16604.99,
#     "delta_diffra": 3.16,
#     "terrain": {
#         "core": 0,
#         "fresnel": 372.5,
#         "boundary": 2369.38
#     },
#     "vegetation": {
#         "core": 0,
#         "fresnel": 0,
#         "boundary": 30
#     },
#     "buildings": {
#         "core": 151.08,
#         "fresnel": 12818.84,
#         "boundary": 27113.12
#     },
#     "terrain_peaks_vv": [
#         {
#             "v_v": 0.5,
#             "d_norm": 0.35
#         },
#         {
#             "v_v": 0.37,
#             "d_norm": 0.91
#         },
#         {
#             "v_v": 0.12,
#             "d_norm": 0.01
#         }
#     ],
#     "max_obstruction_angle_rad": 0,
#     "tx_rx_elevation_angle_rad": -0.0,
#     "tx_near_terminal_clearance_m": 8.0,
#     "rx_near_terminal_clearance_m": 31.19
# }
