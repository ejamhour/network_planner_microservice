# %% [markdown]
# # RPL Points Example With Real Geo Metrics
#
# This notebook uses `points.csv` as the site instance table and `rpl_points_single_interface.toml` as the reusable network profile configuration.
#
# Scenario:
#
# - `itallia` and `torre` are connected tower sites with rank `0`.
# - `deneka` and `saturno` are single-interface relay-capable field sites.
# - All other sites are single-interface leaf field sites.
# - Candidate links are created from `net.connectivity` rules.
# - Edge metrics are computed by `GraphPlanner` using `AsyncGeoServicePool` and the metric profile selected by interface `tech`.
#
# This notebook requires the planning/geo service to be reachable from the Jupyter environment.

# %%
import cisei_lib.planners.graph_planner as gp
import importlib
importlib.reload(gp)
# Out:
# <module 'cisei_lib.planners.graph_planner' from '/workspaces/network_service/cisei_lib/planners/graph_planner.py'>

# %%
from pathlib import Path

import matplotlib.pyplot as plt
import networkx as nx
import pandas as pd

from cisei_lib.io.async_geo_service_pool import AsyncGeoServicePool
from cisei_lib.planners.graph_planner import GraphPlanner
from cisei_lib.planners import planner_reports as reports

# %matplotlib inline

TOWER_IDS = {"itallia", "torre"}
RELAY_IDS = {"deneka", "saturno"}

csv_path = Path("points.csv")
config_path = Path("rpl_points_single_interface.toml")

if not csv_path.exists():
    csv_path = Path("tests/jupyter/points.csv")
if not config_path.exists():
    config_path = Path("tests/jupyter/rpl_points_single_interface.toml")

df = pd.read_csv(csv_path)
df["id"] = df["id"].str.strip()
df
# Out:
#            id        lat        lon  ant_h
# 0       copel -25.432731 -49.339207      7
# 1       tenis -25.425357 -49.292122      7
# 2    praca_29 -25.427624 -49.285643      7
# 3       torre -25.423532 -49.293992    100
# 4    woodland -25.426584 -49.330740      7
# 5      deneka -25.423934 -49.325575      7
# 6   cemiterio -25.420709 -49.313294      7
# 7     saturno -25.427867 -49.343001      7
# 8    decatlon -25.428662 -49.322405      7
# 9    shopping -25.435108 -49.317711      7
# 10    barigui -25.428859 -49.311297      7
# 11     guaira -25.427774 -49.265536      7
# 12    itallia -25.430175 -49.266232     30

# %% [markdown]
# ## 1. Load Profiles And Site Instances
#
# The TOML file defines antennas, interface profiles, device profiles, metrics, and candidate-link rules. The CSV supplies site instances and coordinates. The notebook only assigns each site to a `device_profile`.

# %%
planner_data = GraphPlanner.from_toml(
    config_path,
    working_crs="EPSG:31982",
)

records = df.copy()
records["device_profile"] = "field_node"
records.loc[records["id"].isin(TOWER_IDS), "device_profile"] = "tower"
records.loc[records["id"].isin(RELAY_IDS), "device_profile"] = "relay_node"

planning_nodes = planner_data.add_records(records)
records[["id", "device_profile"]]
# Out:
#            id device_profile
# 0       copel     field_node
# 1       tenis     field_node
# 2    praca_29     field_node
# 3       torre          tower
# 4    woodland     field_node
# 5      deneka     relay_node
# 6   cemiterio     field_node
# 7     saturno     relay_node
# 8    decatlon     field_node
# 9    shopping     field_node
# 10    barigui     field_node
# 11     guaira     field_node
# 12    itallia          tower

# %% [markdown]
# ## 2. Inspect Planner Configuration
#
# `reports.config_table(planner_data, "nodes")` shows the resolved site, device, interface, and antenna information that will be converted into RPL interface nodes.

# %%
config_df = reports.config_table(planner_data, "nodes")
config_df
# Out:
#       site_id   kind        lat        lon              x             y  \
# 0       copel  field -25.432731 -49.339207  667013.250467  7.186095e+06
# 1       tenis  field -25.425357 -49.292122  671759.559806  7.186852e+06
# 2    praca_29  field -25.427624 -49.285643  672408.065400  7.186593e+06
# 3       torre  field -25.423532 -49.293992  671574.031187  7.187057e+06
# 4    woodland  field -25.426584 -49.330740  667873.384644  7.186766e+06
# 5      deneka  field -25.423934 -49.325575  668396.573489  7.187053e+06
# 6   cemiterio  field -25.420709 -49.313294  669636.488343  7.187394e+06
# 7     saturno  field -25.427867 -49.343001  666638.395068  7.186639e+06
# 8    decatlon  field -25.428662 -49.322405  668708.855680  7.186525e+06
# 9    shopping  field -25.435108 -49.317711  669172.039893  7.185805e+06
# 10    barigui  field -25.428859 -49.311297  669825.887515  7.186489e+06
# 11     guaira  field -25.427774 -49.265536  674430.332863  7.186550e+06
# 12    itallia  field -25.430175 -49.266232  674356.864008  7.186285e+06
#
#        device_id  connected  can_route  rank  ...  tx_power_dbm antenna_id  \
# 0       copel:d0      False      False   inf  ...          20.0  omni_demo
# 1       tenis:d0      False      False   inf  ...          20.0  omni_demo
# 2    praca_29:d0      False      False   inf  ...          20.0  omni_demo
# 3       torre:d0       True      False   0.0  ...          43.0  omni_demo
# 4    woodland:d0      False      False   inf  ...          20.0  omni_demo
# 5      deneka:d0      False      False   inf  ...          20.0  omni_demo
# 6   cemiterio:d0      False      False   inf  ...          20.0  omni_demo
# 7     saturno:d0      False      False   inf  ...          20.0  omni_demo
# 8    decatlon:d0      False      False   inf  ...          20.0  omni_demo
# 9    shopping:d0      False      False   inf  ...          20.0  omni_demo
# 10    barigui:d0      False      False   inf  ...          20.0  omni_demo
# 11     guaira:d0      False      False   inf  ...          20.0  omni_demo
# 12    itallia:d0       True      False   0.0  ...          43.0  omni_demo
#
#    can_relay medium  interface_profile  antenna_kind antenna_model  \
# 0      False     rf         field_leaf          omni          None
# 1      False     rf         field_leaf          omni          None
# 2      False     rf         field_leaf          omni          None
# 3      False     rf       tower_access          omni          None
# 4      False     rf         field_leaf          omni          None
# 5       True     rf        field_relay          omni          None
# 6      False     rf         field_leaf          omni          None
# 7       True     rf        field_relay          omni          None
# 8      False     rf         field_leaf          omni          None
# 9      False     rf         field_leaf          omni          None
# 10     False     rf         field_leaf          omni          None
# 11     False     rf         field_leaf          omni          None
# 12     False     rf       tower_access          omni          None
#
#     antenna_gain_dbi antenna_beamwidth_deg antenna_max_links
# 0                0.0                  None              None
# 1                0.0                  None              None
# 2                0.0                  None              None
# 3                0.0                  None              None
# 4                0.0                  None              None
# 5                0.0                  None              None
# 6                0.0                  None              None
# 7                0.0                  None              None
# 8                0.0                  None              None
# 9                0.0                  None              None
# 10               0.0                  None              None
# 11               0.0                  None              None
# 12               0.0                  None              None
#
# [13 rows x 25 columns]

# %% [markdown]
# ## 3. Inspect RPL Nodes
#
# RPL sees interfaces, not physical sites. In this single-interface example, each site contributes one RPL node.

# %%
rpl_table = reports.node_table(planner_data, "rpl")
rpl_table
# Out:
#             node_id    site_id     device_id      tech  freq_mhz  \
# 0       copel:d0:i0      copel      copel:d0  rpl-demo     900.0
# 1       tenis:d0:i0      tenis      tenis:d0  rpl-demo     900.0
# 2    praca_29:d0:i0   praca_29   praca_29:d0  rpl-demo     900.0
# 3       torre:d0:i0      torre      torre:d0  rpl-demo     900.0
# 4    woodland:d0:i0   woodland   woodland:d0  rpl-demo     900.0
# 5      deneka:d0:i0     deneka     deneka:d0  rpl-demo     900.0
# 6   cemiterio:d0:i0  cemiterio  cemiterio:d0  rpl-demo     900.0
# 7     saturno:d0:i0    saturno    saturno:d0  rpl-demo     900.0
# 8    decatlon:d0:i0   decatlon   decatlon:d0  rpl-demo     900.0
# 9    shopping:d0:i0   shopping   shopping:d0  rpl-demo     900.0
# 10    barigui:d0:i0    barigui    barigui:d0  rpl-demo     900.0
# 11     guaira:d0:i0     guaira     guaira:d0  rpl-demo     900.0
# 12    itallia:d0:i0    itallia    itallia:d0  rpl-demo     900.0
#
#     tx_power_dbm antenna_id  mount_height_m  interface_can_relay  connected  \
# 0           20.0  omni_demo             7.0                False      False
# 1           20.0  omni_demo             7.0                False      False
# 2           20.0  omni_demo             7.0                False      False
# 3           43.0  omni_demo           100.0                False       True
# 4           20.0  omni_demo             7.0                False      False
# 5           20.0  omni_demo             7.0                 True      False
# 6           20.0  omni_demo             7.0                False      False
# 7           20.0  omni_demo             7.0                 True      False
# 8           20.0  omni_demo             7.0                False      False
# 9           20.0  omni_demo             7.0                False      False
# 10          20.0  omni_demo             7.0                False      False
# 11          20.0  omni_demo             7.0                False      False
# 12          43.0  omni_demo            30.0                False       True
#
#     rpl_relay  rank              x             y
# 0       False   inf  667013.250467  7.186095e+06
# 1       False   inf  671759.559806  7.186852e+06
# 2       False   inf  672408.065400  7.186593e+06
# 3       False   0.0  671574.031187  7.187057e+06
# 4       False   inf  667873.384644  7.186766e+06
# 5        True   inf  668396.573489  7.187053e+06
# 6       False   inf  669636.488343  7.187394e+06
# 7        True   inf  666638.395068  7.186639e+06
# 8       False   inf  668708.855680  7.186525e+06
# 9       False   inf  669172.039893  7.185805e+06
# 10      False   inf  669825.887515  7.186489e+06
# 11      False   inf  674430.332863  7.186550e+06
# 12      False   0.0  674356.864008  7.186285e+06

# %% [markdown]
# ## 4. Build Candidate Edges
#
# Candidate edges are generated only from `net.connectivity` in the TOML file.

# %%
candidate_edges = planner_data.build_candidate_edges_from_rules()
print("candidate edges:", len(candidate_edges))
reports.edge_table(planner_data, "candidate")
# Out:
# candidate edges: 41
#                 src              dst kind            rule   src_site  \
# 0       torre:d0:i0      tenis:d0:i0   rf  connectivity_0      torre
# 1       torre:d0:i0   praca_29:d0:i0   rf  connectivity_0      torre
# 2       torre:d0:i0    barigui:d0:i0   rf  connectivity_0      torre
# 3       torre:d0:i0  cemiterio:d0:i0   rf  connectivity_0      torre
# 4       torre:d0:i0   shopping:d0:i0   rf  connectivity_0      torre
# 5       torre:d0:i0     guaira:d0:i0   rf  connectivity_0      torre
# 6       torre:d0:i0   decatlon:d0:i0   rf  connectivity_0      torre
# 7       torre:d0:i0     deneka:d0:i0   rf  connectivity_0      torre
# 8       torre:d0:i0   woodland:d0:i0   rf  connectivity_0      torre
# 9       torre:d0:i0      copel:d0:i0   rf  connectivity_0      torre
# 10      torre:d0:i0    saturno:d0:i0   rf  connectivity_0      torre
# 11    itallia:d0:i0     guaira:d0:i0   rf  connectivity_0    itallia
# 12    itallia:d0:i0   praca_29:d0:i0   rf  connectivity_0    itallia
# 13    itallia:d0:i0      tenis:d0:i0   rf  connectivity_0    itallia
# 14    itallia:d0:i0    barigui:d0:i0   rf  connectivity_0    itallia
# 15    itallia:d0:i0  cemiterio:d0:i0   rf  connectivity_0    itallia
# 16    itallia:d0:i0   shopping:d0:i0   rf  connectivity_0    itallia
# 17    itallia:d0:i0   decatlon:d0:i0   rf  connectivity_0    itallia
# 18    itallia:d0:i0     deneka:d0:i0   rf  connectivity_0    itallia
# 19    itallia:d0:i0   woodland:d0:i0   rf  connectivity_0    itallia
# 20    itallia:d0:i0      copel:d0:i0   rf  connectivity_0    itallia
# 21    itallia:d0:i0    saturno:d0:i0   rf  connectivity_0    itallia
# 22      copel:d0:i0    saturno:d0:i0   rf  connectivity_1      copel
# 23      copel:d0:i0     deneka:d0:i0   rf  connectivity_1      copel
# 24      tenis:d0:i0     deneka:d0:i0   rf  connectivity_1      tenis
# 25      tenis:d0:i0    saturno:d0:i0   rf  connectivity_1      tenis
# 26   praca_29:d0:i0     deneka:d0:i0   rf  connectivity_1   praca_29
# 27   praca_29:d0:i0    saturno:d0:i0   rf  connectivity_1   praca_29
# 28   woodland:d0:i0     deneka:d0:i0   rf  connectivity_1   woodland
# 29   woodland:d0:i0    saturno:d0:i0   rf  connectivity_1   woodland
# 30     deneka:d0:i0   decatlon:d0:i0   rf  connectivity_1     deneka
# 31     deneka:d0:i0  cemiterio:d0:i0   rf  connectivity_1     deneka
# 32  cemiterio:d0:i0    saturno:d0:i0   rf  connectivity_1  cemiterio
# 33    saturno:d0:i0     deneka:d0:i0   rf  connectivity_1    saturno
# 34   decatlon:d0:i0    saturno:d0:i0   rf  connectivity_1   decatlon
# 35   shopping:d0:i0     deneka:d0:i0   rf  connectivity_1   shopping
# 36   shopping:d0:i0    saturno:d0:i0   rf  connectivity_1   shopping
# 37    barigui:d0:i0     deneka:d0:i0   rf  connectivity_1    barigui
# 38    barigui:d0:i0    saturno:d0:i0   rf  connectivity_1    barigui
# 39     guaira:d0:i0     deneka:d0:i0   rf  connectivity_1     guaira
# 40     guaira:d0:i0    saturno:d0:i0   rf  connectivity_1     guaira
#
#      dst_site  src_tech  dst_tech  src_freq_mhz  dst_freq_mhz  \
# 0       tenis  rpl-demo  rpl-demo         900.0         900.0
# 1    praca_29  rpl-demo  rpl-demo         900.0         900.0
# 2     barigui  rpl-demo  rpl-demo         900.0         900.0
# 3   cemiterio  rpl-demo  rpl-demo         900.0         900.0
# 4    shopping  rpl-demo  rpl-demo         900.0         900.0
# 5      guaira  rpl-demo  rpl-demo         900.0         900.0
# 6    decatlon  rpl-demo  rpl-demo         900.0         900.0
# 7      deneka  rpl-demo  rpl-demo         900.0         900.0
# 8    woodland  rpl-demo  rpl-demo         900.0         900.0
# 9       copel  rpl-demo  rpl-demo         900.0         900.0
# 10    saturno  rpl-demo  rpl-demo         900.0         900.0
# 11     guaira  rpl-demo  rpl-demo         900.0         900.0
# 12   praca_29  rpl-demo  rpl-demo         900.0         900.0
# 13      tenis  rpl-demo  rpl-demo         900.0         900.0
# 14    barigui  rpl-demo  rpl-demo         900.0         900.0
# 15  cemiterio  rpl-demo  rpl-demo         900.0         900.0
# 16   shopping  rpl-demo  rpl-demo         900.0         900.0
# 17   decatlon  rpl-demo  rpl-demo         900.0         900.0
# 18     deneka  rpl-demo  rpl-demo         900.0         900.0
# 19   woodland  rpl-demo  rpl-demo         900.0         900.0
# 20      copel  rpl-demo  rpl-demo         900.0         900.0
# 21    saturno  rpl-demo  rpl-demo         900.0         900.0
# 22    saturno  rpl-demo  rpl-demo         900.0         900.0
# 23     deneka  rpl-demo  rpl-demo         900.0         900.0
# 24     deneka  rpl-demo  rpl-demo         900.0         900.0
# 25    saturno  rpl-demo  rpl-demo         900.0         900.0
# 26     deneka  rpl-demo  rpl-demo         900.0         900.0
# 27    saturno  rpl-demo  rpl-demo         900.0         900.0
# 28     deneka  rpl-demo  rpl-demo         900.0         900.0
# 29    saturno  rpl-demo  rpl-demo         900.0         900.0
# 30   decatlon  rpl-demo  rpl-demo         900.0         900.0
# 31  cemiterio  rpl-demo  rpl-demo         900.0         900.0
# 32    saturno  rpl-demo  rpl-demo         900.0         900.0
# 33     deneka  rpl-demo  rpl-demo         900.0         900.0
# 34    saturno  rpl-demo  rpl-demo         900.0         900.0
# 35     deneka  rpl-demo  rpl-demo         900.0         900.0
# 36    saturno  rpl-demo  rpl-demo         900.0         900.0
# 37     deneka  rpl-demo  rpl-demo         900.0         900.0
# 38    saturno  rpl-demo  rpl-demo         900.0         900.0
# 39     deneka  rpl-demo  rpl-demo         900.0         900.0
# 40    saturno  rpl-demo  rpl-demo         900.0         900.0
#
#     src_mount_height_m  dst_mount_height_m
# 0                100.0                 7.0
# 1                100.0                 7.0
# 2                100.0                 7.0
# 3                100.0                 7.0
# 4                100.0                 7.0
# 5                100.0                 7.0
# 6                100.0                 7.0
# 7                100.0                 7.0
# 8                100.0                 7.0
# 9                100.0                 7.0
# 10               100.0                 7.0
# 11                30.0                 7.0
# 12                30.0                 7.0
# 13                30.0                 7.0
# 14                30.0                 7.0
# 15                30.0                 7.0
# 16                30.0                 7.0
# 17                30.0                 7.0
# 18                30.0                 7.0
# 19                30.0                 7.0
# 20                30.0                 7.0
# 21                30.0                 7.0
# 22                 7.0                 7.0
# 23                 7.0                 7.0
# 24                 7.0                 7.0
# 25                 7.0                 7.0
# 26                 7.0                 7.0
# 27                 7.0                 7.0
# 28                 7.0                 7.0
# 29                 7.0                 7.0
# 30                 7.0                 7.0
# 31                 7.0                 7.0
# 32                 7.0                 7.0
# 33                 7.0                 7.0
# 34                 7.0                 7.0
# 35                 7.0                 7.0
# 36                 7.0                 7.0
# 37                 7.0                 7.0
# 38                 7.0                 7.0
# 39                 7.0                 7.0
# 40                 7.0                 7.0

# %% [markdown]
# ## 5. Plot Candidate Graph
#
# The plot uses compact `node_index` labels. Use `reports.node_table(planner_data, "rpl")` or `reports.config_table(planner_data, "nodes")` as the index table.

# %%
candidate_graph = planner_data.candidate_graph()
reports.draw_network_graph(candidate_graph)

# %% [markdown]
# ## 6. Compute Real Edge Metrics
#
# The metric profile comes from the TOML `[metrics]` section. `GraphPlanner.compute_edge_metrics(...)` calls the geo service for RF links and stores the metric for each candidate edge.

# %%
geo = AsyncGeoServicePool(
    base_url="http://planning-service:8080",
    user_prefix="rpl-real",
    pool_size=2,
    timeout=120,
)

edge_metrics = await planner_data.compute_edge_metrics(
    geo,
    manage_geo=True,
)

print("computed edge metrics:", len(edge_metrics))
# Out:
# APIResult(kind='json')
# APIResult(kind='json')
# computed edge metrics: 41

# %%
metric_table = reports.edge_table(planner_data, "metric")
metric_table
# Out:
#                 src              dst kind            rule   src_site  \
# 0       torre:d0:i0      tenis:d0:i0   rf  connectivity_0      torre
# 1       torre:d0:i0   praca_29:d0:i0   rf  connectivity_0      torre
# 2       torre:d0:i0    barigui:d0:i0   rf  connectivity_0      torre
# 3       torre:d0:i0  cemiterio:d0:i0   rf  connectivity_0      torre
# 4       torre:d0:i0   shopping:d0:i0   rf  connectivity_0      torre
# 5       torre:d0:i0     guaira:d0:i0   rf  connectivity_0      torre
# 6       torre:d0:i0   decatlon:d0:i0   rf  connectivity_0      torre
# 7       torre:d0:i0     deneka:d0:i0   rf  connectivity_0      torre
# 8       torre:d0:i0      copel:d0:i0   rf  connectivity_0      torre
# 9       torre:d0:i0    saturno:d0:i0   rf  connectivity_0      torre
# 10    itallia:d0:i0     guaira:d0:i0   rf  connectivity_0    itallia
# 11    itallia:d0:i0   praca_29:d0:i0   rf  connectivity_0    itallia
# 12    itallia:d0:i0      tenis:d0:i0   rf  connectivity_0    itallia
# 13      copel:d0:i0    saturno:d0:i0   rf  connectivity_1      copel
# 14   woodland:d0:i0    saturno:d0:i0   rf  connectivity_1   woodland
# 15      tenis:d0:i0     deneka:d0:i0   rf  connectivity_1      tenis
# 16    saturno:d0:i0     deneka:d0:i0   rf  connectivity_1    saturno
# 17      tenis:d0:i0    saturno:d0:i0   rf  connectivity_1      tenis
# 18    itallia:d0:i0     deneka:d0:i0   rf  connectivity_0    itallia
# 19    itallia:d0:i0    saturno:d0:i0   rf  connectivity_0    itallia
# 20   shopping:d0:i0     deneka:d0:i0   rf  connectivity_1   shopping
# 21    itallia:d0:i0      copel:d0:i0   rf  connectivity_0    itallia
# 22      torre:d0:i0   woodland:d0:i0   rf  connectivity_0      torre
# 23    itallia:d0:i0  cemiterio:d0:i0   rf  connectivity_0    itallia
# 24     guaira:d0:i0    saturno:d0:i0   rf  connectivity_1     guaira
# 25    itallia:d0:i0   decatlon:d0:i0   rf  connectivity_0    itallia
# 26     guaira:d0:i0     deneka:d0:i0   rf  connectivity_1     guaira
# 27   woodland:d0:i0     deneka:d0:i0   rf  connectivity_1   woodland
# 28   praca_29:d0:i0     deneka:d0:i0   rf  connectivity_1   praca_29
# 29    itallia:d0:i0   shopping:d0:i0   rf  connectivity_0    itallia
# 30    itallia:d0:i0   woodland:d0:i0   rf  connectivity_0    itallia
# 31    barigui:d0:i0    saturno:d0:i0   rf  connectivity_1    barigui
# 32      copel:d0:i0     deneka:d0:i0   rf  connectivity_1      copel
# 33   praca_29:d0:i0    saturno:d0:i0   rf  connectivity_1   praca_29
# 34     deneka:d0:i0   decatlon:d0:i0   rf  connectivity_1     deneka
# 35   decatlon:d0:i0    saturno:d0:i0   rf  connectivity_1   decatlon
# 36    barigui:d0:i0     deneka:d0:i0   rf  connectivity_1    barigui
# 37    itallia:d0:i0    barigui:d0:i0   rf  connectivity_0    itallia
# 38   shopping:d0:i0    saturno:d0:i0   rf  connectivity_1   shopping
# 39     deneka:d0:i0  cemiterio:d0:i0   rf  connectivity_1     deneka
# 40  cemiterio:d0:i0    saturno:d0:i0   rf  connectivity_1  cemiterio
#
#      dst_site  src_tech  dst_tech  src_freq_mhz  dst_freq_mhz  \
# 0       tenis  rpl-demo  rpl-demo         900.0         900.0
# 1    praca_29  rpl-demo  rpl-demo         900.0         900.0
# 2     barigui  rpl-demo  rpl-demo         900.0         900.0
# 3   cemiterio  rpl-demo  rpl-demo         900.0         900.0
# 4    shopping  rpl-demo  rpl-demo         900.0         900.0
# 5      guaira  rpl-demo  rpl-demo         900.0         900.0
# 6    decatlon  rpl-demo  rpl-demo         900.0         900.0
# 7      deneka  rpl-demo  rpl-demo         900.0         900.0
# 8       copel  rpl-demo  rpl-demo         900.0         900.0
# 9     saturno  rpl-demo  rpl-demo         900.0         900.0
# 10     guaira  rpl-demo  rpl-demo         900.0         900.0
# 11   praca_29  rpl-demo  rpl-demo         900.0         900.0
# 12      tenis  rpl-demo  rpl-demo         900.0         900.0
# 13    saturno  rpl-demo  rpl-demo         900.0         900.0
# 14    saturno  rpl-demo  rpl-demo         900.0         900.0
# 15     deneka  rpl-demo  rpl-demo         900.0         900.0
# 16     deneka  rpl-demo  rpl-demo         900.0         900.0
# 17    saturno  rpl-demo  rpl-demo         900.0         900.0
# 18     deneka  rpl-demo  rpl-demo         900.0         900.0
# 19    saturno  rpl-demo  rpl-demo         900.0         900.0
# 20     deneka  rpl-demo  rpl-demo         900.0         900.0
# 21      copel  rpl-demo  rpl-demo         900.0         900.0
# 22   woodland  rpl-demo  rpl-demo         900.0         900.0
# 23  cemiterio  rpl-demo  rpl-demo         900.0         900.0
# 24    saturno  rpl-demo  rpl-demo         900.0         900.0
# 25   decatlon  rpl-demo  rpl-demo         900.0         900.0
# 26     deneka  rpl-demo  rpl-demo         900.0         900.0
# 27     deneka  rpl-demo  rpl-demo         900.0         900.0
# 28     deneka  rpl-demo  rpl-demo         900.0         900.0
# 29   shopping  rpl-demo  rpl-demo         900.0         900.0
# 30   woodland  rpl-demo  rpl-demo         900.0         900.0
# 31    saturno  rpl-demo  rpl-demo         900.0         900.0
# 32     deneka  rpl-demo  rpl-demo         900.0         900.0
# 33    saturno  rpl-demo  rpl-demo         900.0         900.0
# 34   decatlon  rpl-demo  rpl-demo         900.0         900.0
# 35    saturno  rpl-demo  rpl-demo         900.0         900.0
# 36     deneka  rpl-demo  rpl-demo         900.0         900.0
# 37    barigui  rpl-demo  rpl-demo         900.0         900.0
# 38    saturno  rpl-demo  rpl-demo         900.0         900.0
# 39  cemiterio  rpl-demo  rpl-demo         900.0         900.0
# 40    saturno  rpl-demo  rpl-demo         900.0         900.0
#
#     src_mount_height_m  dst_mount_height_m   metric
# 0                100.0                 7.0    1.000
# 1                100.0                 7.0    1.000
# 2                100.0                 7.0    1.000
# 3                100.0                 7.0    1.000
# 4                100.0                 7.0    1.000
# 5                100.0                 7.0    1.000
# 6                100.0                 7.0    1.000
# 7                100.0                 7.0    1.000
# 8                100.0                 7.0    1.000
# 9                100.0                 7.0    1.000
# 10                30.0                 7.0    1.000
# 11                30.0                 7.0    1.000
# 12                30.0                 7.0    1.000
# 13                 7.0                 7.0    1.000
# 14                 7.0                 7.0    1.000
# 15                 7.0                 7.0    1.150
# 16                 7.0                 7.0    1.735
# 17                 7.0                 7.0    1.795
# 18                30.0                 7.0    1.980
# 19                30.0                 7.0    2.080
# 20                 7.0                 7.0    3.520
# 21                30.0                 7.0    7.680
# 22               100.0                 7.0    9.900
# 23                30.0                 7.0   25.705
# 24                 7.0                 7.0   25.705
# 25                30.0                 7.0   26.400
# 26                 7.0                 7.0   26.400
# 27                 7.0                 7.0   29.280
# 28                 7.0                 7.0   50.905
# 29                30.0                 7.0   52.905
# 30                30.0                 7.0   60.220
# 31                 7.0                 7.0   60.220
# 32                 7.0                 7.0   62.400
# 33                 7.0                 7.0   64.620
# 34                 7.0                 7.0   85.105
# 35                 7.0                 7.0   90.345
# 36                 7.0                 7.0  108.480
# 37                30.0                 7.0  138.025
# 38                 7.0                 7.0  144.705
# 39                 7.0                 7.0  241.705
# 40                 7.0                 7.0  273.345

# %% [markdown]
# ## 7. Run RPL

# %%
planner_data.run_rpl()
planner_data.rpl_result_counts()
# Out:
# {'nodes': 13, 'edges': 11}

# %% [markdown]
# ## 8. Inspect Results
#
# `reports.node_table(planner_data, "result")` contains the selected parent and rank per RPL node.

# %%
result_df = reports.node_table(planner_data, "result")
result_df
# Out:
#     node_index          node_id    site_id     device_id         parent  \
# 0            0      copel:d0:i0      copel      copel:d0    torre:d0:i0
# 1            1      tenis:d0:i0      tenis      tenis:d0  itallia:d0:i0
# 2            2   praca_29:d0:i0   praca_29   praca_29:d0  itallia:d0:i0
# 3            3      torre:d0:i0      torre      torre:d0            NaN
# 4            4   woodland:d0:i0   woodland   woodland:d0  saturno:d0:i0
# 5            5     deneka:d0:i0     deneka     deneka:d0    torre:d0:i0
# 6            6  cemiterio:d0:i0  cemiterio  cemiterio:d0    torre:d0:i0
# 7            7    saturno:d0:i0    saturno    saturno:d0    torre:d0:i0
# 8            8   decatlon:d0:i0   decatlon   decatlon:d0    torre:d0:i0
# 9            9   shopping:d0:i0   shopping   shopping:d0    torre:d0:i0
# 10          10    barigui:d0:i0    barigui    barigui:d0    torre:d0:i0
# 11          11     guaira:d0:i0     guaira     guaira:d0  itallia:d0:i0
# 12          12    itallia:d0:i0    itallia    itallia:d0            NaN
#
#     parent_index parent_site_id  connected  rpl_relay  rank  \
# 0            3.0          torre      False      False   1.0
# 1           12.0        itallia      False      False   1.0
# 2           12.0        itallia      False      False   1.0
# 3            NaN            NaN       True      False   0.0
# 4            7.0        saturno      False      False   2.0
# 5            3.0          torre      False       True   1.0
# 6            3.0          torre      False      False   1.0
# 7            3.0          torre      False       True   1.0
# 8            3.0          torre      False      False   1.0
# 9            3.0          torre      False      False   1.0
# 10           3.0          torre      False      False   1.0
# 11          12.0        itallia      False      False   1.0
# 12           NaN            NaN       True      False   0.0
#
#     interface_can_relay  can_relay
# 0                 False      False
# 1                 False      False
# 2                 False      False
# 3                 False      False
# 4                 False      False
# 5                  True       True
# 6                 False      False
# 7                  True       True
# 8                 False      False
# 9                 False      False
# 10                False      False
# 11                False      False
# 12                False      False

# %%
summary_df = result_df.loc[
    ~result_df["connected"],
    ["node_index", "site_id", "parent_index", "parent_site_id", "rank"],
].sort_values("site_id")
summary_df
# Out:
#     node_index    site_id  parent_index parent_site_id  rank
# 10          10    barigui           3.0          torre   1.0
# 6            6  cemiterio           3.0          torre   1.0
# 0            0      copel           3.0          torre   1.0
# 8            8   decatlon           3.0          torre   1.0
# 5            5     deneka           3.0          torre   1.0
# 11          11     guaira          12.0        itallia   1.0
# 2            2   praca_29          12.0        itallia   1.0
# 7            7    saturno           3.0          torre   1.0
# 9            9   shopping           3.0          torre   1.0
# 1            1      tenis          12.0        itallia   1.0
# 4            4   woodland           7.0        saturno   2.0

# %%
reports.edge_table(planner_data, "result")
# Out:
#                src              dst kind            rule  src_site   dst_site  \
# 0      copel:d0:i0      torre:d0:i0   rf  connectivity_0     copel      torre
# 1      tenis:d0:i0    itallia:d0:i0   rf  connectivity_0     tenis    itallia
# 2   praca_29:d0:i0    itallia:d0:i0   rf  connectivity_0  praca_29    itallia
# 3      torre:d0:i0     deneka:d0:i0   rf  connectivity_0     torre     deneka
# 4      torre:d0:i0  cemiterio:d0:i0   rf  connectivity_0     torre  cemiterio
# 5      torre:d0:i0    saturno:d0:i0   rf  connectivity_0     torre    saturno
# 6      torre:d0:i0   decatlon:d0:i0   rf  connectivity_0     torre   decatlon
# 7      torre:d0:i0   shopping:d0:i0   rf  connectivity_0     torre   shopping
# 8      torre:d0:i0    barigui:d0:i0   rf  connectivity_0     torre    barigui
# 9   woodland:d0:i0    saturno:d0:i0   rf  connectivity_1  woodland    saturno
# 10    guaira:d0:i0    itallia:d0:i0   rf  connectivity_0    guaira    itallia
#
#     src_tech  dst_tech  src_freq_mhz  dst_freq_mhz  src_mount_height_m  \
# 0   rpl-demo  rpl-demo         900.0         900.0                 7.0
# 1   rpl-demo  rpl-demo         900.0         900.0                 7.0
# 2   rpl-demo  rpl-demo         900.0         900.0                 7.0
# 3   rpl-demo  rpl-demo         900.0         900.0               100.0
# 4   rpl-demo  rpl-demo         900.0         900.0               100.0
# 5   rpl-demo  rpl-demo         900.0         900.0               100.0
# 6   rpl-demo  rpl-demo         900.0         900.0               100.0
# 7   rpl-demo  rpl-demo         900.0         900.0               100.0
# 8   rpl-demo  rpl-demo         900.0         900.0               100.0
# 9   rpl-demo  rpl-demo         900.0         900.0                 7.0
# 10  rpl-demo  rpl-demo         900.0         900.0                 7.0
#
#     dst_mount_height_m  metric
# 0                100.0     1.0
# 1                 30.0     1.0
# 2                 30.0     1.0
# 3                  7.0     1.0
# 4                  7.0     1.0
# 5                  7.0     1.0
# 6                  7.0     1.0
# 7                  7.0     1.0
# 8                  7.0     1.0
# 9                  7.0     1.0
# 10                30.0     1.0

# %% [markdown]
# ## 9. Plot Result Graph

# %%
reports.draw_network_graph(planner_data.rpl.G_res)
