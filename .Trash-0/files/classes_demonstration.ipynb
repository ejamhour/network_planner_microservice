# %%
# Planning classes model
#
# Identity rule:
#   RPL vertices are radio interfaces.
#   Interface IDs use: position:radio:interface 
#
# Example:
#   torre:r0:i0
#     position = torre
#     radio    = r0
#     interface = i0
#
# Antenna is a property of the interface.
# Technology is a property of the radio.
# Position owns geographic/projected coordinates.

from math import inf

from cisei_lib.planners.planner_classes import (
    AntennaSpec,
    FieldSite,
    RadioInterface,
    Site,
    Device,
    RPLNode,
    TowerSite,
    get_utm_epsg,
    make_interface_id,
)

WORKING_CRS = "EPSG:31982"  # SIRGAS 2000 / UTM zone 22S

print('dumb')
# Out:
# Failed to connect to the remote Jupyter Server 'http://127.0.0.1:8888/'. Verify the server is running and reachable. ('_xsrf' argument missing from POST).
