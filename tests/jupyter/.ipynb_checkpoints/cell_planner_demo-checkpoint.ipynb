# %% [markdown]
# # CellPlanner Demo
#
# This notebook runs the tower/cell planning workflow from a complete `PlanningScenario` bundle. Scenario creation belongs in `scenario_builder.ipynb`; this notebook only loads the exported scenario, builds sector-aware candidates, computes metrics, runs RPL, and inspects the result.

# %%
from pathlib import Path
import sys
import pandas as pd

import importlib
import cisei_lib.planners.cell_planner as cp
importlib.reload(cp)

NOTEBOOK_DIR = Path.cwd()
REPO_ROOT = NOTEBOOK_DIR.parents[1]
if str(REPO_ROOT) not in sys.path:
    sys.path.insert(0, str(REPO_ROOT))

from cisei_lib.io.async_geo_service_pool import AsyncGeoServicePool
from cisei_lib.planners import CellPlanner, PlanningScenario
import cisei_lib.planners.planner_reports as reports
importlib.reload(reports)

SCENARIO_PATH = NOTEBOOK_DIR / "scenario_exports" / "cell_planner_sector_antenna.toml"
RESULT_DIR = NOTEBOOK_DIR / "planning_results"
RESULT_DIR.mkdir(parents=True, exist_ok=True)

GEO_BASE_URL = "http://planning-service:8080"
GEO_USER_PREFIX = "cell-planner-demo"
GEO_POOL_SIZE = 1
RANK_THRESHOLD = 2.0

# %% [markdown]
# ## 1. Load Scenario
#
# The TOML points to its companion `.nodes.csv`, so tower/client profile assignments are already part of the scenario.

# %%
scenario = PlanningScenario.from_toml(SCENARIO_PATH)
cell = CellPlanner(scenario, primary_tech="lte")

print("scenario:", SCENARIO_PATH.name)
print("validation errors:", scenario.validate())
print("sites:", len(cell.graph.nodes))
print("interfaces:", len(cell.graph.rpl_nodes))

# %%
display(reports.config_table(cell.graph, "antennas"))
display(reports.config_table(cell.graph, "interfaces"))

# %% [markdown]
# ## 2. Build Candidate Graph
#
# This is the cheap pre-geo stage. `CellPlanner` uses sector azimuth and beamwidth to reject impossible cell-to-client links before feature extraction.

# %%
candidate_edges = cell.build_primary_candidates(
    sector_aware=True,
    limit_m=None,
    degree=None,
)

print("candidate edges:", len(candidate_edges))
display(cell.sector_candidate_table())
display(reports.edge_table(cell.graph, "candidate"))

# %%
reports.draw_network_graph(
    cell.graph.candidate_graph(),
    label_mode="site",
    figsize=(10, 7),
    spread_same_position=True,
    spread_radius=150,
)

# %% [markdown]
# ## 3. Optional Sector Tuning
#
# Run this before metric computation. Rotation and pruning only rebuild the candidate graph, so they are cheap to inspect and repeat.

# %%
tuning = cell.tune_sectors(
    apply_rotation=False,
    prune_empty=False,
    step_deg=5.0,
    uncovered_weight=10.0,
    imbalance_weight=1.0,
    sector_aware=True,
    limit_m=None,
    degree=None,
)

print("candidate edges:", tuning["candidate_edges"])
display(tuning["rotation"])
display(tuning["prune"])
display(tuning["sectors"])

# %% [markdown]
# ## 4. Compute Real Metrics
#
# `CellPlanner` delegates metric computation to `GraphPlanner`. Function-based antenna gains from `model_id` are included in the metric records.

# %%
geo = AsyncGeoServicePool(
    base_url=GEO_BASE_URL,
    user_prefix=GEO_USER_PREFIX,
    pool_size=GEO_POOL_SIZE,
    timeout=180,
)

await geo.start()
metrics = await cell.compute_metrics(geo, manage_geo=False)

print("computed metrics:", len(metrics))
display(reports.edge_table(cell.graph, "metric").head(20))

# %%
reports.antenna_gain_table(cell.graph).head(20)

# %% [markdown]
# ## 5. Run RPL
#
# RPL selects the planned cell/sector connection from the metric graph.

# %%
cell.run_rpl()
cell.graph.rpl_result_counts()

# %%
quality_summary = reports.planning_quality_summary(
    cell.graph,
    rank_threshold=RANK_THRESHOLD,
)
quality_table = reports.planning_quality_table(
    cell.graph,
    rank_threshold=RANK_THRESHOLD,
)

print(quality_summary)
display(quality_table)
display(cell.service_table())
display(reports.edge_table(cell.graph, "result"))

# %%
G_quality = reports.planning_result_graph(cell.graph, include_all_nodes=True)

reports.draw_network_graph(
    G_quality,
    label_mode="index",
    color_mode="rank_quality",
    rank_threshold=RANK_THRESHOLD,
    figsize=(10, 7),
    spread_same_position=True,
    spread_radius=100,
)

reports.planning_quality_summary(cell.graph, rank_threshold=RANK_THRESHOLD)
reports.planning_quality_table(cell.graph, rank_threshold=RANK_THRESHOLD)
# Out:
# {'rank_threshold': 2.0,
#  'success': False,
#  'total_targets': 11,
#  'good_targets': 8,
#  'poor_targets': 3,
#  'unserved_targets': 0,
#  'counts': {'good': 8, 'connected': 5, 'poor': 3}}

# %% [markdown]
# ## 6. Save Result

# %%
result_path = RESULT_DIR / f"{SCENARIO_PATH.stem}.result.json"
cell.graph.save_results(result_path, include_features=True)
result_path

# %% [markdown]
# ## 7. Cleanup

# %%
await geo.close()
