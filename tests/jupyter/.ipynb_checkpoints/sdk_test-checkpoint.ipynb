# %%
# !pip install --upgrade --no-cache-dir \
  --root-user-action=ignore \
  --trusted-host network-service \
  --index-url http://network-service:8080/sdk/simple \
  cisei-planning-sdk
# Out:
# Looking in indexes: http://network-service:8080/sdk/simple
# Requirement already satisfied: cisei-planning-sdk in /usr/local/lib/python3.12/site-packages (0.1.5)
# Requirement already satisfied: requests>=2.28.0 in /usr/local/lib/python3.12/site-packages (from cisei-planning-sdk) (2.34.2)
# Requirement already satisfied: tomlkit>=0.12.0 in /usr/local/lib/python3.12/site-packages (from cisei-planning-sdk) (0.15.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/site-packages (from requests>=2.28.0->cisei-planning-sdk) (3.5.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/site-packages (from requests>=2.28.0->cisei-planning-sdk) (3.19)
# Requirement already satisfied: urllib3<3,>=1.26 in /usr/local/lib/python3.12/site-packages (from requests>=2.28.0->cisei-planning-sdk) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in /usr/local/lib/python3.12/site-packages (from requests>=2.28.0->cisei-planning-sdk) (2026.7.22)

# %%
from cisei_planning_sdk import PlanningClient, __version__

print(__version__)

client = PlanningClient("http://network-service:8080", 
                        user_id="my_notebook",
                        timeout=900)

scenario = client.define_scenario(
    name="sdk_test",
    planner="cell",
    scenario="scenario_exports/cell_planner_sector_antenna.toml",
)

candidate_edges = scenario.build_candidate_edges()
candidate_edges["counts"]
# Out:
# 0.1.5
# {'sites': 13,
#  'rpl_nodes': 16,
#  'candidate_edges': 21,
#  'metric_edges': 0,
#  'planned_nodes': 0,
#  'planned_edges': 0}

# %%
metrics = scenario.compute_metrics()
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File /usr/local/lib/python3.12/site-packages/urllib3/connectionpool.py:534, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     533 try:
# --> 534     response = conn.getresponse()
#     535 except (BaseSSLError, OSError) as e:
#
# File /usr/local/lib/python3.12/site-packages/urllib3/connection.py:571, in HTTPConnection.getresponse(self)
#     570 # Get the response from http.client.HTTPConnection
# --> 571 httplib_response = super().getresponse()
#     573 try:
#
# File /usr/local/lib/python3.12/http/client.py:1478, in HTTPConnection.getresponse(self)
#    1477 try:
# -> 1478     response.begin()
#    1479 except ConnectionError:
#
# File /usr/local/lib/python3.12/http/client.py:343, in HTTPResponse.begin(self)
#     342 for _ in range(_MAXINTERIMRESPONSES):
# --> 343     version, status, reason = self._read_status()
#     344     if status != CONTINUE:
#
# File /usr/local/lib/python3.12/http/client.py:304, in HTTPResponse._read_status(self)
#     303 def _read_status(self):
# --> 304     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     305     if len(line) > _MAXLINE:
#
# File /usr/local/lib/python3.12/socket.py:720, in SocketIO.readinto(self, b)
#     719 try:
# --> 720     return self._sock.recv_into(b)
#     721 except timeout:
#
# TimeoutError: timed out
#
# The above exception was the direct cause of the following exception:
#
# ReadTimeoutError                          Traceback (most recent call last)
# File /usr/local/lib/python3.12/site-packages/requests/adapters.py:696, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     695 try:
# --> 696     resp = conn.urlopen(
#     697         method=request.method,
#     698         url=url,
#     699         body=request.body,  # type: ignore[arg-type]  # urllib3 stubs don't accept Iterable[bytes | str]
#     700         headers=request.headers,  # type: ignore[arg-type]  # urllib3#3072
#     701         redirect=False,
#     702         assert_same_host=False,
#     703         preload_content=False,
#     704         decode_content=False,
#     705         retries=self.max_retries,
#     706         timeout=resolved_timeout,
#     707         chunked=chunked,
#     708     )
#     710 except (ProtocolError, OSError) as err:
#
# File /usr/local/lib/python3.12/site-packages/urllib3/connectionpool.py:842, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     840     new_e = ProtocolError("Connection aborted.", new_e)
# --> 842 retries = retries.increment(
#     843     method, url, error=new_e, _pool=self, _stacktrace=sys.exc_info()[2]
#     844 )
#     845 retries.sleep()
#
# File /usr/local/lib/python3.12/site-packages/urllib3/util/retry.py:498, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     497 if read is False or method is None or not self._is_method_retryable(method):
# --> 498     raise reraise(type(error), error, _stacktrace)
#     499 elif read is not None:
#
# File /usr/local/lib/python3.12/site-packages/urllib3/util/util.py:39, in reraise(tp, value, tb)
#      38         raise value.with_traceback(tb)
# ---> 39     raise value
#      40 finally:
#
# File /usr/local/lib/python3.12/site-packages/urllib3/connectionpool.py:788, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     787 # Make the request on the HTTPConnection object
# --> 788 response = self._make_request(
#     789     conn,
#     790     method,
#     791     url,
#     792     timeout=timeout_obj,
#     793     body=body,
#     794     headers=headers,
#     795     chunked=chunked,
#     796     retries=retries,
#     797     response_conn=response_conn,
#     798     preload_content=preload_content,
#     799     decode_content=decode_content,
#     800     **response_kw,
#     801 )
#     803 # Everything went great!
#
# File /usr/local/lib/python3.12/site-packages/urllib3/connectionpool.py:536, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     535 except (BaseSSLError, OSError) as e:
# --> 536     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#     537     raise
#
# File /usr/local/lib/python3.12/site-packages/urllib3/connectionpool.py:367, in HTTPConnectionPool._raise_timeout(self, err, url, timeout_value)
#     366 if isinstance(err, SocketTimeout):
# --> 367     raise ReadTimeoutError(
#     368         self, url, f"Read timed out. (read timeout={timeout_value})"
#     369     ) from err
#     371 # See the above comment about EAGAIN in Python 3.
#
# ReadTimeoutError: HTTPConnectionPool(host='network-service', port=8080): Read timed out. (read timeout=120.0)
#
# During handling of the above exception, another exception occurred:
#
# ReadTimeout                               Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 metrics = scenario.compute_metrics()
#
# File /usr/local/lib/python3.12/site-packages/cisei_planning_sdk/session.py:101, in ScenarioSession.compute_metrics(self, geo_base_url, geo_user_prefix, geo_pool_size, geo_timeout, include_features)
#      84 def compute_metrics(
#      85     self,
#      86     *,
#    (...)     91     include_features: bool = False,
#      92 ) -> dict[str, Any]:
#      93     """
#      94     Compute real edge metrics through the external features service.
#      95
#    (...)     99     configured for each interface technology.
#     100     """
# --> 101     payload = self.client._request(
#     102         "post",
#     103         f"/planning/scenarios/{self.scenario_id}/metrics/compute",
#     104         json={
#     105             "edge_metrics": None,
#     106             "include_features": include_features,
#     107             "geo_base_url": geo_base_url,
#     108             "geo_user_prefix": geo_user_prefix,
#     109             "geo_pool_size": geo_pool_size,
#     110             "geo_timeout": geo_timeout,
#     111         },
#     112     )
#     113     self.metrics = payload["data"]
#     114     return self.metrics
#
# File /usr/local/lib/python3.12/site-packages/cisei_planning_sdk/client.py:122, in PlanningClient._request(self, method, path, **kwargs)
#     119 headers = dict(kwargs.pop("headers", {}) or {})
#     120 headers["X-Token"] = self.token
# --> 122 response = self.session.request(
#     123     method,
#     124     url,
#     125     headers=headers,
#     126     timeout=self.timeout,
#     127     **kwargs,
#     128 )
#     129 response.raise_for_status()
#     131 payload = response.json()
#
# File /usr/local/lib/python3.12/site-packages/requests/sessions.py:651, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     646 send_kwargs = {
#     647     "timeout": timeout,
#     648     "allow_redirects": allow_redirects,
#     649 }
#     650 send_kwargs.update(settings)
# --> 651 resp = self.send(prep, **send_kwargs)
#     653 return resp
#
# File /usr/local/lib/python3.12/site-packages/requests/sessions.py:784, in Session.send(self, request, **kwargs)
#     781 start = preferred_clock()
#     783 # Send the request
# --> 784 r = adapter.send(request, **kwargs)
#     786 # Total elapsed time of the request (approximately)
#     787 elapsed = preferred_clock() - start
#
# File /usr/local/lib/python3.12/site-packages/requests/adapters.py:742, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     740     raise SSLError(e, request=request)
#     741 elif isinstance(e, ReadTimeoutError):
# --> 742     raise ReadTimeout(e, request=request)
#     743 elif isinstance(e, _InvalidHeader):
#     744     raise InvalidHeader(e, request=request)
#
# ReadTimeout: HTTPConnectionPool(host='network-service', port=8080): Read timed out. (read timeout=120.0)

# %%
metrics = scenario.compute_metrics(
    geo_base_url="http://planning-service:8080",
    geo_pool_size=2,
    include_features=False,
)

# %%
solution = scenario.solve()

solution["counts"]
solution["planned_edges"][:5]
